# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

SAVEFIG_PATH = '../reports/figures/'
SAFE_FIGURES = False

# %%
registrations = pd.read_csv('../datafiles/links/LINKS_Zeeland_cleaned_2016_01_Registrations.csv', sep=';')
persons = pd.read_csv('../datafiles/links/LINKS_Zeeland_cleaned_2016_01_Persons.csv', sep=';')
locations = pd.read_csv('../datafiles/links/LINKS_Zeeland_cleaned_2016_01_Locations_v2.csv', sep=';')
# Out:
# /home/wouter/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (3,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/wouter/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (14,21,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print "Aantal registraties: ", registrations.id_registration.unique().shape[0]
print "Jaar eerste registratie: ", registrations.registration_year.unique().min()
print "Jaar laatste registratie: ", registrations.registration_year.unique().max()
# Out:
# Aantal registraties:  1558205
# Jaar eerste registratie:  1796
# Jaar laatste registratie:  1969

# %%
y = registrations[['registration_maintype','registration_year', 'id_registration']].groupby(['registration_year','registration_maintype']).count().rename(columns={'id_registration':'Count'})
y = y[y.Count > 22]
y.min()
# Out:
# Count    55
# dtype: int64

# %%
years_per_bin = 1
num_bins = ((registrations.registration_year.unique().max() - registrations.registration_year.unique().min()) / years_per_bin) + 1
bins = np.linspace(registrations.registration_year.unique().min(), registrations.registration_year.unique().max(), num_bins)
registrations.groupby(['registration_maintype', 'registration_year'])

#plt.show()
y = registrations[['registration_maintype','registration_year', 'id_registration']].groupby(['registration_year','registration_maintype']).count().rename(columns={'id_registration':'Count'})
y = y[y.Count > 22]
ax = y.unstack().plot(title="Number of registration per year", figsize=(10,4))
ax.set_ylabel('Number of registrations')
ax.set_xlabel('Year')
ax.legend(['Birth Certificates', 'Marriage certificates', 'Death certificates'])
fig = ax.get_figure()
if SAVE_FIGURES: fig.savefig(SAVEFIG_PATH + 'opbouw_registrations.png', bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-9154814da290> in <module>()
#      12 ax.legend(['Birth Certificates', 'Marriage certificates', 'Death certificates'])
#      13 fig = ax.get_figure()
# ---> 14 if SAVE_FIGURES: fig.savefig(SAVEFIG_PATH + 'opbouw_registrations.png', bbox_inches='tight')
#      15 plt.show()
#
# NameError: name 'SAVE_FIGURES' is not defined

# %%
registrations[registrations.registration_maintype == 3].sort_values(['registration_year'], ascending=False)
# Out:
#          id_registration  registration_maintype registration_type extract  \
# 1200478          1200909                      3                 o     NaN
# 1516472          1517076                      3                 o     NaN
# 985162            985520                      3                 o     NaN
# 1280977          1281447                      3                 o     NaN
# 1365425          1365931                      3                 o     NaN
# 1242733          1243186                      3                 o     NaN
# 899952            900286                      3                 o     NaN
# 1285369          1285840                      3                 o     NaN
# 979508            979864                      3                 o     NaN
# 910635            910971                      3                 o     NaN
# 1367706          1368215                      3                 o     NaN
# 1353854          1354354                      3                 o     NaN
# 1262203          1262665                      3                 o     NaN
# 992974            993335                      3                 o     NaN
# 1444608          1445165                      3                 o     NaN
# 1007366          1007731                      3                 o     NaN
# 1324156          1324642                      3                 o     NaN
# 1289064          1289536                      3                 o     NaN
# 1497691          1498280                      3                 o     NaN
# 1154376          1154783                      3                 o     NaN
# 1265214          1265678                      3                 o     NaN
# 971271            971624                      3                 o     NaN
# 895557            895890                      3                 o     NaN
# 1089447          1089834                      3                 o     NaN
# 980761            981117                      3                 o     NaN
# 980808            981164                      3                 o     NaN
# 1436553          1437105                      3                 o     NaN
# 1117286          1117681                      3                 o     NaN
# 1020759          1021127                      3                 o     NaN
# 1172453          1172865                      3                 o     NaN
# ...                  ...                    ...               ...     ...
# 1213067          1213506                      3                 o     NaN
# 895145            895478                      3                 o     NaN
# 1418216          1418757                      3                 o     NaN
# 1321648          1322134                      3                 o     NaN
# 1381341          1381857                      3                 o     NaN
# 1076397          1076779                      3                 o     NaN
# 1216911          1217353                      3                 o     NaN
# 990463            990824                      3                 o     NaN
# 1001490          1001852                      3                 o     NaN
# 1092224          1092613                      3                 o     NaN
# 1515997          1516600                      3                 o     NaN
# 1215826          1216267                      3                 o     NaN
# 1448001          1448559                      3                 o     NaN
# 1012234          1012599                      3                 o     NaN
# 1349106          1349603                      3                 o     NaN
# 1366088          1366594                      3                 o     NaN
# 913981            914317                      3                 o     NaN
# 945206            945547                      3                 o     NaN
# 1394913          1395439                      3                 o     NaN
# 913744            914080                      3                 o     NaN
# 1335415          1335907                      3                 o     NaN
# 1268601          1269067                      3                 o     NaN
# 1147921          1148323                      3                 o     NaN
# 1001289          1001651                      3                 o     NaN
# 970135            970487                      3                 o     NaN
# 1007399          1007764                      3                 o     NaN
# 1507839          1508431                      3                 o     NaN
# 945765            946106                      3                 o     NaN
# 1418976          1419517                      3                 o     NaN
# 1296849          1297329                      3                 o     NaN
#
#          registration_location  registration_day  registration_month  \
# 1200478                 4098.0                 2                   9
# 1516472                 4098.0                29                   5
# 985162                  4098.0                22                   5
# 1280977                 4098.0                21                   2
# 1365425                 4098.0                 5                   5
# 1242733                 4098.0                 5                   8
# 899952                  4098.0                29                   6
# 1285369                 4098.0                21                   7
# 979508                  4098.0                13                   8
# 910635                  4098.0                16                   8
# 1367706                 4098.0                 6                   1
# 1353854                 4098.0                 8                   7
# 1262203                 4098.0                19                   7
# 992974                  3362.0                18                   9
# 1444608                 1998.0                 2                   2
# 1007366                 9890.0                 9                   2
# 1324156                 4047.0                10                   1
# 1289064                  598.0                12                   9
# 1497691                 5434.0                21                   3
# 1154376                  608.0                22                   1
# 1265214                 2625.0                19                   4
# 971271                   608.0                28                   9
# 895557                  2625.0                 4                   4
# 1089447                 1359.0                23                  12
# 980761                  2025.0                20                   9
# 980808                  1889.0                21                   2
# 1436553                 2007.0                22                   2
# 1117286                 3364.0                27                  12
# 1020759                 3908.0                21                   7
# 1172453                 2007.0                 8                   1
# ...                        ...               ...                 ...
# 1213067                  413.0                20                  10
# 895145                  7028.0                16                   9
# 1418216                 4047.0                26                   8
# 1321648                 3486.0                26                   9
# 1381341                 2625.0                12                   9
# 1076397                 1807.0                 5                  12
# 1216911                 1016.0                29                   9
# 990463                  7028.0                13                  11
# 1001490                  674.0                21                   9
# 1092224                 2625.0                23                  10
# 1515997                 3486.0                24                  11
# 1215826                 3240.0                24                   9
# 1448001                 3486.0                11                  12
# 1012234                 3577.0                 2                  10
# 1349106                 1722.0                20                   8
# 1366088                 3513.0                14                  11
# 913981                  3513.0                17                  11
# 945206                   674.0                 5                  11
# 1394913                   17.0                14                  10
# 913744                  3486.0                23                  12
# 1335415                 4047.0                31                  12
# 1268601                 2533.0                20                  11
# 1147921                 1807.0                26                  10
# 1001289                 6176.0                27                  11
# 970135                  5434.0                23                  11
# 1007399                 1724.0                18                   9
# 1507839                 3355.0                11                   9
# 945765                  1689.0                15                  12
# 1418976                 3240.0                15                  11
# 1296849                 3577.0                12                  10
#
#          registration_year registration_seq  registration_flag
# 1200478               1966                2                NaN
# 1516472               1966                5                NaN
# 985162                1966                4                NaN
# 1280977               1966                1                NaN
# 1365425               1966                3                NaN
# 1242733               1965                3                NaN
# 899952                1965                1                NaN
# 1285369               1965                2                NaN
# 979508                1965                4                NaN
# 910635                1964                4                NaN
# 1367706               1964                1                NaN
# 1353854               1964                2                NaN
# 1262203               1964                3                NaN
# 992974                1963                4                NaN
# 1444608               1963                3                NaN
# 1007366               1963               36                NaN
# 1324156               1963                2                NaN
# 1289064               1963               17                NaN
# 1497691               1963               37                NaN
# 1154376               1963                1                NaN
# 1265214               1963               47                NaN
# 971271                1963               12                NaN
# 895557                1963               41                NaN
# 1089447               1963              268                NaN
# 980761                1963               25                NaN
# 980808                1963                8                NaN
# 1436553               1963                9                NaN
# 1117286               1963               18                NaN
# 1020759               1963               20                NaN
# 1172453               1963                1                NaN
# ...                    ...              ...                ...
# 1213067               1796                4                NaN
# 895145                1796              NaN                NaN
# 1418216               1796              NaN                NaN
# 1321648               1796                1                NaN
# 1381341               1796              NaN                NaN
# 1076397               1796               12                NaN
# 1216911               1796                1                NaN
# 990463                1796                3                NaN
# 1001490               1796              NaN                NaN
# 1092224               1796                3                NaN
# 1515997               1796               16                NaN
# 1215826               1796                1                NaN
# 1448001               1796               19                NaN
# 1012234               1796                3                NaN
# 1349106               1796              NaN                NaN
# 1366088               1796                4                NaN
# 913981                1796                5                NaN
# 945206                1796                4                NaN
# 1394913               1796                3                NaN
# 913744                1796               21                NaN
# 1335415               1796                8                NaN
# 1268601               1796                5                NaN
# 1147921               1796                4                NaN
# 1001289               1796                4                NaN
# 970135                1796                6                NaN
# 1007399               1796              NaN                NaN
# 1507839               1796              NaN                NaN
# 945765                1796                7                NaN
# 1418976               1796               10                NaN
# 1296849               1796                5                NaN
#
# [665999 rows x 10 columns]

# %%
print "Aantal geboorte-akten: ", registrations[registrations.registration_maintype==1].shape[0]
print "Aantal trouwakten: ", registrations[registrations.registration_maintype==2].shape[0]
print "Aantal overlijdensakten: ", registrations[registrations.registration_maintype==3].shape[0]
# Out:
# Aantal geboorte-akten:  698285
# Aantal trouwakten:  193921
# Aantal overlijdensakten:  665999

# %%
from collections import Counter
unieke_voornamen = Counter()
unieke_mannen_voornamen = Counter()
unieke_vrouwen_voornamen = Counter()

# %%
voornamen = persons.firstname.fillna('Geen_naam').str.split(' ').apply(unieke_voornamen.update)
voornamen_mannen = persons[persons.sex == 'm'].firstname.fillna('Geen_naam').str.split(' ').apply(unieke_mannen_voornamen.update)
voornamen_vouwen = persons[persons.sex == 'f'].firstname.fillna('Geen_naam').str.split(' ').apply(unieke_vrouwen_voornamen.update)

# %%
print unieke_voornamen.most_common(100)
print unieke_mannen_voornamen.most_common(100)
print unieke_vrouwen_voornamen.most_common(100)
# Out:
# [('maria', 405128), ('pieter', 254606), ('johanna', 234204), ('jan', 230823), ('cornelis', 213435), ('cornelia', 198172), ('johannes', 189151), ('Geen_naam', 179941), ('jacobus', 166204), ('pieternella', 148507), ('adriana', 143932), ('catharina', 132243), ('adriaan', 125410), ('marinus', 117102), ('willem', 108309), ('anna', 106928), ('jacoba', 94175), ('jacob', 85682), ('abraham', 78250), ('janna', 76565), ('maatje', 73064), ('elisabeth', 72949), ('elizabeth', 63657), ('neeltje', 62700), ('hendrik', 58231), ('petrus', 54889), ('franciscus', 51028), ('jannetje', 49882), ('johannis', 48925), ('sara', 47704), ('leendert', 47556), ('wilhelmina', 42252), ('levenloos', 41989), ('willemina', 41336), ('jacomina', 38860), ('suzanna', 37314), ('francies', 35515), ('josephus', 34891), ('marie', 33829), ('dina', 31018), ('lena', 29712), ('christina', 29688), ('helena', 28874), ('izaak', 27980), ('sophia', 26947), ('bernardus', 26747), ('tannetje', 26142), ('magdalena', 26073), ('jozina', 25716), ('francois', 24885), ('andries', 24444), ('theresia', 23643), ('francina', 23108), ('apolonia', 21327), ('susanna', 21012), ('leuntje', 20851), ('rosalia', 20598), ('hendrika', 20124), ('francisca', 20069), ('louisa', 19973), ('jean', 19698), ('petronella', 19501), ('jannis', 19264), ('martina', 18678), ('ludovicus', 18545), ('janneke', 18274), ('daniel', 18121), ('joseph', 18083), ('kornelis', 17824), ('anthonie', 17823), ('christiaan', 17524), ('paulina', 17477), ('joannes', 17425), ('nicolaas', 17371), ('dirk', 17206), ('geertruida', 16627), ('adrianus', 16511), ('augustinus', 15462), ('levina', 15216), ('johan', 14988), ('louis', 14772), ('jakob', 14354), ('anthonij', 13712), ('frederik', 13552), ('frans', 13503), ('joanna', 13312), ('charles', 13160), ('pierre', 13020), ('gerard', 12640), ('josina', 12525), ('gerrit', 12402), ('martinus', 12356), ('simon', 12339), ('amelia', 12113), ('david', 11966), ('gerardus', 11937), ('kornelia', 11812), ('isabella', 11733), ('carolina', 11406), ('margaretha', 11264)]
# [('pieter', 254368), ('jan', 230618), ('cornelis', 212994), ('johannes', 188896), ('jacobus', 166046), ('adriaan', 125207), ('Geen_naam', 117733), ('marinus', 117021), ('willem', 108234), ('jacob', 85541), ('abraham', 78136), ('hendrik', 58166), ('petrus', 54818), ('franciscus', 50953), ('johannis', 48869), ('leendert', 47519), ('francies', 35487), ('josephus', 34838), ('izaak', 27949), ('bernardus', 26716), ('francois', 24813), ('andries', 24404), ('levenloos', 20823), ('jean', 19654), ('jannis', 19251), ('ludovicus', 18505), ('daniel', 18100), ('kornelis', 17795), ('anthonie', 17775), ('joseph', 17609), ('christiaan', 17502), ('joannes', 17401), ('nicolaas', 17349), ('dirk', 17182), ('adrianus', 16495), ('augustinus', 15447), ('johan', 14946), ('louis', 14732), ('jakob', 14348), ('anthonij', 13691), ('frederik', 13537), ('frans', 13490), ('charles', 13144), ('pierre', 13008), ('gerard', 12633), ('gerrit', 12388), ('martinus', 12314), ('simon', 12313), ('david', 11934), ('gerardus', 11921), ('carolus', 11167), ('karel', 10789), ('judocus', 10481), ('eduardus', 10473), ('maarten', 10335), ('jozias', 9961), ('paulus', 9796), ('levinus', 9771), ('mattheus', 9532), ('joost', 8952), ('isaac', 8892), ('dominicus', 8258), ('joos', 8223), ('gillis', 8064), ('theodorus', 7850), ('philippus', 7786), ('krijn', 7714), ('leonardus', 7671), ('wilhelmus', 7478), ('antonius', 7401), ('gilles', 7388), ('matthijs', 7098), ('hermanus', 7051), ('bastiaan', 6964), ('machiel', 6870), ('thomas', 6868), ('baptiste', 6781), ('arie', 6587), ('hubrecht', 6561), ('arij', 6475), ('laurens', 6434), ('hendrikus', 6430), ('izak', 6170), ('dingenis', 5737), ('klaas', 5703), ('augustus', 5659), ('aarnout', 5588), ('anthonius', 5564), ('alphonsus', 5470), ('hubregt', 5361), ('albertus', 5283), ('jacques', 5119), ('samuel', 5075), ('job', 5073), ('janus', 5048), ('alexander', 5026), ('hubertus', 4954), ('jakobus', 4849), ('lambertus', 4821), ('lodewijk', 4807)]
# [('maria', 402464), ('johanna', 233901), ('cornelia', 197931), ('pieternella', 148416), ('adriana', 143786), ('catharina', 132143), ('anna', 106828), ('jacoba', 94079), ('janna', 76528), ('maatje', 73011), ('elisabeth', 72884), ('elizabeth', 63604), ('neeltje', 62661), ('Geen_naam', 62129), ('jannetje', 49851), ('sara', 47681), ('wilhelmina', 42202), ('willemina', 41316), ('jacomina', 38846), ('suzanna', 37298), ('dina', 30997), ('marie', 30481), ('lena', 29690), ('christina', 29656), ('helena', 28853), ('sophia', 26912), ('tannetje', 26131), ('magdalena', 26054), ('jozina', 25693), ('theresia', 23630), ('francina', 23094), ('apolonia', 21303), ('susanna', 20997), ('leuntje', 20840), ('rosalia', 20574), ('hendrika', 20097), ('francisca', 20039), ('louisa', 19942), ('petronella', 19492), ('martina', 18659), ('janneke', 18262), ('paulina', 17456), ('geertruida', 16617), ('levenloos', 15836), ('levina', 15199), ('joanna', 13291), ('josina', 12513), ('amelia', 12100), ('kornelia', 11797), ('isabella', 11727), ('carolina', 11395), ('margaretha', 11255), ('adriaantje', 9495), ('judoca', 9063), ('krina', 8722), ('marina', 8098), ('katharina', 8015), ('jeanne', 7853), ('aaltje', 7726), ('anthonia', 7632), ('anne', 7437), ('seraphina', 7431), ('grietje', 7310), ('coleta', 7099), ('ludovica', 6923), ('dorothea', 6784), ('geertje', 6574), ('philomena', 6507), ('tanneke', 6369), ('alida', 6331), ('barbara', 6285), ('kaatje', 6233), ('antonia', 6158), ('martha', 6113), ('leintje', 6056), ('mathilda', 5800), ('laurina', 5799), ('angelina', 5748), ('tona', 5729), ('geertruid', 5651), ('francoise', 5406), ('klazina', 5221), ('clasina', 5047), ('josephina', 4853), ('josepha', 4830), ('frederika', 4747), ('louise', 4718), ('clara', 4664), ('regina', 4643), ('emma', 4569), ('leonie', 4545), ('dingena', 4427), ('jakoba', 4377), ('rozalia', 4300), ('hendrina', 4158), ('stoffelina', 4147), ('anthonetta', 4020), ('dirkje', 4011), ('leijntje', 3718), ('rachel', 3672)]

# %%
registrations[(registrations.registration_year == 1810) | (registrations.registration_year == 1811)][['registration_year', 'registration_location', 'id_registration']].groupby(['registration_year', 'registration_location']).count().unstack(level=0)
# Out:
#                       id_registration
# registration_year                1810    1811
# registration_location
# 4.0                               NaN    36.0
# 17.0                             96.0   102.0
# 166.0                             NaN   107.0
# 201.0                           206.0   205.0
# 208.0                             NaN    52.0
# 413.0                           124.0   113.0
# 415.0                             NaN    31.0
# 484.0                             NaN    36.0
# 524.0                             NaN    66.0
# 527.0                            46.0    48.0
# 566.0                           134.0   142.0
# 578.0                             NaN    27.0
# 598.0                             NaN    89.0
# 608.0                             NaN   102.0
# 652.0                             NaN    38.0
# 664.0                             NaN    15.0
# 674.0                            67.0    64.0
# 721.0                           146.0   166.0
# 729.0                             NaN   139.0
# 933.0                             NaN    66.0
# 947.0                             NaN    45.0
# 973.0                             NaN     5.0
# 1016.0                           88.0   107.0
# 1072.0                            NaN    24.0
# 1075.0                            NaN    32.0
# 1078.0                            NaN    32.0
# 1190.0                            NaN     2.0
# 1219.0                            NaN    39.0
# 1255.0                            NaN    15.0
# 1359.0                            NaN   422.0
# ...                               ...     ...
# 3902.0                            NaN   172.0
# 3915.0                            NaN     5.0
# 3919.0                            NaN    34.0
# 4000.0                            NaN     1.0
# 4001.0                            NaN   133.0
# 4017.0                            NaN   112.0
# 4045.0                            NaN    85.0
# 4047.0                          147.0   123.0
# 4088.0                            NaN   670.0
# 4097.0                            NaN    32.0
# 4098.0                            NaN    28.0
# 4107.0                           54.0    54.0
# 4121.0                           60.0    72.0
# 5434.0                          136.0   174.0
# 6082.0                            NaN     3.0
# 6176.0                           51.0    60.0
# 7028.0                           62.0    79.0
# 8369.0                            NaN     8.0
# 8402.0                            NaN    11.0
# 8520.0                            NaN    54.0
# 8521.0                            NaN    13.0
# 9119.0                            NaN     6.0
# 9325.0                            NaN    14.0
# 9452.0                            NaN     1.0
# 9453.0                            NaN     9.0
# 9459.0                            NaN    29.0
# 9622.0                            NaN     6.0
# 9860.0                            NaN     2.0
# 9890.0                            NaN  3233.0
# 10010.0                           NaN    54.0
#
# [139 rows x 2 columns]

# %%
birth_candidates = pd.read_csv('../datafiles/links/input/geboorte_ouders.csv', sep="|", index_col=False, header=None)
mar_candidates = pd.read_csv('../datafiles/links/input/huwelijk_ouders.csv', sep="|", index_col=False, header=None)
death_candidates = pd.read_csv('../datafiles/links/input/overlijden_ouders.csv', sep="|", index_col=False, header=None)

# %%
birth_candidates.columns = ['id', 'first_name_male', 'fam_name_male', 'first_name_female', 'fam_name_female']
mar_candidates.columns = ['id', 'first_name_male', 'fam_name_male', 'first_name_female', 'fam_name_female']
death_candidates.columns = ['id', 'first_name_male', 'fam_name_male', 'first_name_female', 'fam_name_female']

# %%
birth_candidates['len_vnm'] = birth_candidates.first_name_male.str.len().fillna(0).astype(int)
birth_candidates['len_fnm'] = birth_candidates.fam_name_male.str.len().fillna(0).astype(int)
birth_candidates['len_vnv'] = birth_candidates.first_name_female.str.len().fillna(0).astype(int)
birth_candidates['len_fnv'] = birth_candidates.fam_name_female.str.len().fillna(0).astype(int)

# %%
mar_candidates['len_vnm'] = mar_candidates.first_name_male.str.len().fillna(0).astype(int)
mar_candidates['len_fnm'] = mar_candidates.fam_name_male.str.len().fillna(0).astype(int)
mar_candidates['len_vnv'] = mar_candidates.first_name_female.str.len().fillna(0).astype(int)
mar_candidates['len_fnv'] = mar_candidates.fam_name_female.str.len().fillna(0).astype(int)

# %%
death_candidates['len_vnm'] = death_candidates.first_name_male.str.len().fillna(0).astype(int)
death_candidates['len_fnm'] = death_candidates.fam_name_male.str.len().fillna(0).astype(int)
death_candidates['len_vnv'] = death_candidates.first_name_female.str.len().fillna(0).astype(int)
death_candidates['len_fnv'] = death_candidates.fam_name_female.str.len().fillna(0).astype(int)

# %%
all_registrations = pd.DataFrame().append(birth_candidates).append(mar_candidates).append(death_candidates)

# %%
fig, ax = plt.subplots()
all_registrations[['len_vnm', 'len_fnm', 'len_vnv', 'len_fnv']].boxplot()
ax.set_xticklabels(['first name male', 'fam name male', 'fist name female', 'fam name female'], rotation=50, ha='right')
ax.set_title("Spread of the length of names, split by sex and type")
ax.set_ylabel('Length of the name')
fig.savefig('../reports/figures/spread_of_name_length', bbox_inches='tight')
plt.show()

# %%
all_registrations[['len_vnm', 'len_fnm', 'len_vnv', 'len_fnv']].describe()
# Out:
#             len_vnm       len_fnm       len_vnv       len_fnv
# count  1.750182e+06  1.750182e+06  1.750182e+06  1.750182e+06
# mean   6.095911e+00  6.265960e+00  6.791278e+00  6.466958e+00
# std    2.302867e+00  2.656707e+00  2.228525e+00  2.421217e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
# 50%    7.000000e+00  6.000000e+00  7.000000e+00  6.000000e+00
# 75%    8.000000e+00  8.000000e+00  8.000000e+00  8.000000e+00
# max    1.600000e+01  3.300000e+01  1.700000e+01  3.100000e+01
