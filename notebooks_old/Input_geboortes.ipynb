# %%
import os, sys
import pandas as pd
import numpy as np
import mysql.connector

stdout = sys.stdout
reload(sys)
sys.setdefaultencoding('latin-1')
sys.stdout = stdout

# %%
conn = mysql.connector.connect(host='localhost', database='links_zeeland', user='root', password='3016BE_17e') 
fathers = pd.read_sql("SELECT id_registration, firstname, familyname FROM persons WHERE registration_maintype = 1 and role = 3", con=conn)
mothers = pd.read_sql('SELECT id_registration, firstname, familyname FROM persons WHERE registration_maintype = 1 and role = 2', con=conn)
conn.close()
# Out:
#        id_registration
# count    698218.000000
# mean     349253.007211
# std      201655.811865
# min           1.000000
# 25%      174607.250000
# 50%      349247.500000
# 75%      523891.750000
# max      698557.000000

# %%
merged = fathers.merge(mothers, on='id_registration')
merged.columns = ['id_registration', 'fname_p_m', 'lname_p_m', 'fname_p_f', 'lname_p_f']
merged.fname_p_m = merged.fname_p_m.apply(lambda s: s.split(' ')[0])
merged.fname_p_f = merged.fname_p_f.apply(lambda s: s.split(' ')[0])
merged
# Out:
#         id_registration   fname_p_m     lname_p_m   fname_p_f    lname_p_f
# 0                     1        joos       stevens  franciesca         laat
# 1                     2      petrus     vermeulen       maria         kock
# 2                     3  theophilus       ververs      sophia    hulstaert
# 3                     4    johannes    verwilghen    angelina   verwilghen
# 4                     5     hendrik       meijers   catharina       wattel
# 5                     6   bernardus    verstraete      louisa      lecleir
# 6                     7     marinus          rijk    tannetje       remijn
# 7                     8       janes      schipper    cornelia   lindenberg
# 8                     9      pieter          beun       maria          vos
# 9                    10    dingenis       verburg       maria       kramer
# 10                   11     marinus    schroevers   roberdina         baak
# ...

# %%
merged.to_csv('datafiles/links/input/geboorte_ouders.csv', header=False, index=False, sep='|', line_terminator='\n')
